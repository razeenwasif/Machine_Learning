# %% [markdown]
# **COMP3670/6670 Tutorial Week 10**
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 0: MNIST Dataset (Recap)

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
digits,labels = datasets.load_digits(return_X_y=True)
X = digits
y = labels

def print_heatmap(data, l=8, h=8):
    plt.matshow(data.reshape(l,h), cmap=plt.cm.gray)

print_heatmap(X[42]) #print digits

# %%
TEST_SIZE = 0.5
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=TEST_SIZE)

print("Total dataset", np.shape(X))
print("Split dataset (Train)", np.shape(X_train))
print("Split dataset (Test)", np.shape(X_test))
# Out:
# Total dataset (1797, 64)
# Split dataset (Train) (898, 64)
# Split dataset (Test) (899, 64)

# %% [markdown]
# # MLP

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning
from sklearn.neural_network import MLPClassifier

#The MLP input layer has 64 pixel inputs (8x8 image). The output layer predicts 10 labels. 
#Hidden layers form connected perceptron between input and output layers.
#(64,32) denotes a first layer with 64 perceptrons connected to the input layer, 
#then another hidden layer with 32 perceptrons connected to the first hidden layer
#and to the output layer. How do these choices matter? 
# hidden_layers = (64,32)
hidden_layers = (64,)
max_iterations = 10
#Max iterations is set to 10. Can you set it higher? Will a higher value ensure every iteration is used?

mlp = MLPClassifier(hidden_layer_sizes=hidden_layers, max_iter=max_iterations, activation = 'logistic', random_state=42, verbose=1)

with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=ConvergenceWarning, module="sklearn")
    mlp.fit(X_train, y_train) #Code to catch convergence warnings

print("Training set score: %f" % mlp.score(X_train, y_train))
print("Test set score: %f" % mlp.score(X_test, y_test))
# Out:
# Iteration 1, loss = 2.32553814
# Iteration 2, loss = 2.13760250
# Iteration 3, loss = 2.00424110
# Iteration 4, loss = 1.89045962
# Iteration 5, loss = 1.77778621
# Iteration 6, loss = 1.67032034
# Iteration 7, loss = 1.57105427
# Iteration 8, loss = 1.47740961
# Iteration 9, loss = 1.38970631
# Iteration 10, loss = 1.30880741
# Training set score: 0.844098
# Test set score: 0.779755

# %%
#Visualising hidden layer weights
import math
for i, layer in enumerate(hidden_layers):
    fig, axes = plt.subplots(1, layer, figsize=(30, 10))
    vmin, vmax = mlp.coefs_[i].min(), mlp.coefs_[i].max()
    for coef, ax in zip(mlp.coefs_[i].T, axes.ravel()):
        #display square subset
        mat_side = math.floor(math.sqrt(len(coef)))
        #For visualising only showing the largest square matrix the weights represent
        ax.matshow(coef[:mat_side*mat_side].reshape(mat_side, mat_side), cmap=plt.cm.gray, vmin=vmin, vmax=vmax)
        ax.set_xticks(())
        ax.set_yticks(())
    
plt.show()

# %% [markdown]
# # Task: Test score vs max iterations

# %%
#Can you try the same MLP with different max_iterations up to 1000? 
# What is the test score mlp.score(X_test, y_test)?
#Try to plot this
mlp = MLPClassifier(hidden_layer_sizes=hidden_layers, max_iter=1000, activation = 'logistic', random_state=42, verbose=1)

with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=ConvergenceWarning, module="sklearn")
    mlp.fit(X_train, y_train) #Code to catch convergence warnings

print("Training set score: %f" % mlp.score(X_train, y_train))
print("Test set score: %f" % mlp.score(X_test, y_test))
# Out:
# Iteration 1, loss = 2.32553814
# Iteration 2, loss = 2.13760250
# Iteration 3, loss = 2.00424110
# Iteration 4, loss = 1.89045962
# Iteration 5, loss = 1.77778621
# Iteration 6, loss = 1.67032034
# Iteration 7, loss = 1.57105427
# Iteration 8, loss = 1.47740961
# Iteration 9, loss = 1.38970631
# Iteration 10, loss = 1.30880741
# Iteration 11, loss = 1.23469836
# Iteration 12, loss = 1.16459035
# Iteration 13, loss = 1.09896164
# Iteration 14, loss = 1.03857948
# Iteration 15, loss = 0.98230907
# Iteration 16, loss = 0.92972116
# Iteration 17, loss = 0.88008891
# Iteration 18, loss = 0.83392495
# Iteration 19, loss = 0.78978578
# Iteration 20, loss = 0.74941794
# Iteration 21, loss = 0.71107438
# Iteration 22, loss = 0.67568678
# Iteration 23, loss = 0.64192756
# Iteration 24, loss = 0.61054829
# Iteration 25, loss = 0.58122591
# Iteration 26, loss = 0.55438283
# Iteration 27, loss = 0.52878399
# Iteration 28, loss = 0.50465858
# Iteration 29, loss = 0.48283482
# Iteration 30, loss = 0.46250743
# Iteration 31, loss = 0.44263177
# Iteration 32, loss = 0.42472286
# Iteration 33, loss = 0.40742342
# Iteration 34, loss = 0.39155291
# Iteration 35, loss = 0.37631550
# Iteration 36, loss = 0.36187622
# Iteration 37, loss = 0.34873864
# Iteration 38, loss = 0.33571437
# Iteration 39, loss = 0.32458657
# Iteration 40, loss = 0.31301010
# Iteration 41, loss = 0.30183428
# Iteration 42, loss = 0.29203013
# Iteration 43, loss = 0.28217710
# Iteration 44, loss = 0.27315221
# Iteration 45, loss = 0.26435265
# Iteration 46, loss = 0.25669128
# Iteration 47, loss = 0.24820111
# Iteration 48, loss = 0.24112360
# Iteration 49, loss = 0.23418843
# Iteration 50, loss = 0.22694818
# Iteration 51, loss = 0.22077650
# Iteration 52, loss = 0.21474197
# Iteration 53, loss = 0.20904228
# Iteration 54, loss = 0.20342788
# Iteration 55, loss = 0.19789184
# Iteration 56, loss = 0.19233238
# Iteration 57, loss = 0.18767883
# Iteration 58, loss = 0.18242450
# Iteration 59, loss = 0.17797189
# Iteration 60, loss = 0.17385829
# Iteration 61, loss = 0.16940037
# Iteration 62, loss = 0.16548763
# Iteration 63, loss = 0.16139094
# Iteration 64, loss = 0.15768484
# Iteration 65, loss = 0.15388143
# Iteration 66, loss = 0.15062284
# Iteration 67, loss = 0.14719801
# Iteration 68, loss = 0.14397352
# Iteration 69, loss = 0.14096348
# Iteration 70, loss = 0.13804353
# Iteration 71, loss = 0.13510700
# Iteration 72, loss = 0.13243371
# Iteration 73, loss = 0.12961859
# Iteration 74, loss = 0.12692376
# Iteration 75, loss = 0.12431335
# Iteration 76, loss = 0.12187550
# Iteration 77, loss = 0.11959436
# Iteration 78, loss = 0.11733955
# Iteration 79, loss = 0.11496238
# Iteration 80, loss = 0.11274789
# Iteration 81, loss = 0.11064689
# Iteration 82, loss = 0.10870664
# Iteration 83, loss = 0.10656169
# Iteration 84, loss = 0.10467277
# Iteration 85, loss = 0.10285049
# Iteration 86, loss = 0.10074412
# Iteration 87, loss = 0.09942886
# Iteration 88, loss = 0.09747919
# Iteration 89, loss = 0.09578247
# Iteration 90, loss = 0.09415445
# Iteration 91, loss = 0.09236449
# Iteration 92, loss = 0.09073166
# Iteration 93, loss = 0.08928615
# Iteration 94, loss = 0.08774937
# Iteration 95, loss = 0.08620653
# Iteration 96, loss = 0.08497811
# Iteration 97, loss = 0.08349020
# Iteration 98, loss = 0.08207462
# Iteration 99, loss = 0.08084641
# Iteration 100, loss = 0.07961988
# Iteration 101, loss = 0.07832489
# Iteration 102, loss = 0.07704668
# Iteration 103, loss = 0.07586422
# Iteration 104, loss = 0.07468246
# Iteration 105, loss = 0.07340967
# Iteration 106, loss = 0.07244697
# Iteration 107, loss = 0.07135175
# Iteration 108, loss = 0.07011468
# Iteration 109, loss = 0.06897869
# Iteration 110, loss = 0.06807766
# Iteration 111, loss = 0.06697196
# Iteration 112, loss = 0.06613238
# Iteration 113, loss = 0.06519930
# Iteration 114, loss = 0.06400915
# Iteration 115, loss = 0.06324293
# Iteration 116, loss = 0.06225968
# Iteration 117, loss = 0.06143225
# Iteration 118, loss = 0.06053832
# Iteration 119, loss = 0.05973559
# Iteration 120, loss = 0.05885677
# Iteration 121, loss = 0.05815053
# Iteration 122, loss = 0.05738392
# Iteration 123, loss = 0.05646753
# Iteration 124, loss = 0.05569928
# Iteration 125, loss = 0.05500500
# Iteration 126, loss = 0.05421617
# Iteration 127, loss = 0.05349687
# Iteration 128, loss = 0.05279877
# Iteration 129, loss = 0.05211999
# Iteration 130, loss = 0.05147060
# Iteration 131, loss = 0.05075701
# Iteration 132, loss = 0.05010768
# Iteration 133, loss = 0.04945704
# Iteration 134, loss = 0.04877227
# Iteration 135, loss = 0.04822817
# Iteration 136, loss = 0.04755097
# Iteration 137, loss = 0.04697483
# Iteration 138, loss = 0.04637933
# Iteration 139, loss = 0.04576874
# Iteration 140, loss = 0.04522297
# Iteration 141, loss = 0.04477041
# Iteration 142, loss = 0.04414098
# Iteration 143, loss = 0.04352110
# Iteration 144, loss = 0.04330964
# Iteration 145, loss = 0.04262451
# Iteration 146, loss = 0.04219508
# Iteration 147, loss = 0.04166185
# Iteration 148, loss = 0.04109151
# Iteration 149, loss = 0.04058192
# Iteration 150, loss = 0.04020892
# Iteration 151, loss = 0.03964583
# Iteration 152, loss = 0.03938374
# Iteration 153, loss = 0.03884250
# Iteration 154, loss = 0.03827287
# Iteration 155, loss = 0.03791668
# Iteration 156, loss = 0.03753792
# Iteration 157, loss = 0.03712893
# Iteration 158, loss = 0.03673446
# Iteration 159, loss = 0.03619376
# Iteration 160, loss = 0.03575096
# Iteration 161, loss = 0.03546230
# Iteration 162, loss = 0.03510431
# Iteration 163, loss = 0.03470122
# Iteration 164, loss = 0.03430557
# Iteration 165, loss = 0.03387957
# Iteration 166, loss = 0.03354234
# Iteration 167, loss = 0.03323183
# Iteration 168, loss = 0.03278416
# Iteration 169, loss = 0.03248612
# Iteration 170, loss = 0.03222264
# Iteration 171, loss = 0.03184359
# Iteration 172, loss = 0.03144700
# Iteration 173, loss = 0.03118112
# Iteration 174, loss = 0.03086022
# Iteration 175, loss = 0.03048028
# Iteration 176, loss = 0.03015422
# Iteration 177, loss = 0.02984089
# Iteration 178, loss = 0.02950182
# Iteration 179, loss = 0.02924367
# Iteration 180, loss = 0.02893393
# Iteration 181, loss = 0.02860075
# Iteration 182, loss = 0.02833088
# Iteration 183, loss = 0.02804464
# Iteration 184, loss = 0.02775289
# Iteration 185, loss = 0.02750144
# Iteration 186, loss = 0.02718642
# Iteration 187, loss = 0.02697384
# Iteration 188, loss = 0.02666142
# Iteration 189, loss = 0.02639064
# Iteration 190, loss = 0.02613518
# Iteration 191, loss = 0.02582073
# Iteration 192, loss = 0.02557131
# Iteration 193, loss = 0.02540679
# Iteration 194, loss = 0.02517746
# Iteration 195, loss = 0.02483269
# Iteration 196, loss = 0.02459604
# Iteration 197, loss = 0.02439508
# Iteration 198, loss = 0.02419235
# Iteration 199, loss = 0.02394702
# Iteration 200, loss = 0.02367124
# Iteration 201, loss = 0.02345048
# Iteration 202, loss = 0.02328116
# Iteration 203, loss = 0.02301099
# Iteration 204, loss = 0.02279336
# Iteration 205, loss = 0.02262605
# Iteration 206, loss = 0.02246629
# Iteration 207, loss = 0.02223558
# Iteration 208, loss = 0.02203440
# Iteration 209, loss = 0.02181644
# Iteration 210, loss = 0.02162968
# Iteration 211, loss = 0.02142666
# Iteration 212, loss = 0.02123530
# Iteration 213, loss = 0.02107105
# Iteration 214, loss = 0.02089955
# Iteration 215, loss = 0.02071172
# Iteration 216, loss = 0.02052420
# Iteration 217, loss = 0.02036413
# Iteration 218, loss = 0.02015468
# Iteration 219, loss = 0.01999990
# Iteration 220, loss = 0.01982345
# Iteration 221, loss = 0.01965571
# Iteration 222, loss = 0.01951119
# Iteration 223, loss = 0.01933318
# Iteration 224, loss = 0.01918721
# Iteration 225, loss = 0.01899807
# Iteration 226, loss = 0.01887296
# Iteration 227, loss = 0.01867099
# Iteration 228, loss = 0.01851251
# Iteration 229, loss = 0.01838515
# Iteration 230, loss = 0.01824843
# Iteration 231, loss = 0.01808145
# Iteration 232, loss = 0.01794391
# Iteration 233, loss = 0.01778181
# Iteration 234, loss = 0.01763908
# Iteration 235, loss = 0.01751110
# Iteration 236, loss = 0.01737801
# Iteration 237, loss = 0.01722928
# Iteration 238, loss = 0.01709290
# Iteration 239, loss = 0.01697905
# Iteration 240, loss = 0.01679420
# Iteration 241, loss = 0.01668392
# Iteration 242, loss = 0.01657886
# Iteration 243, loss = 0.01644846
# Iteration 244, loss = 0.01629476
# Iteration 245, loss = 0.01616802
# Iteration 246, loss = 0.01605463
# Iteration 247, loss = 0.01590930
# Iteration 248, loss = 0.01583304
# Iteration 249, loss = 0.01566534
# Iteration 250, loss = 0.01558428
# Iteration 251, loss = 0.01547129
# Iteration 252, loss = 0.01534140
# Iteration 253, loss = 0.01521819
# Iteration 254, loss = 0.01509457
# Iteration 255, loss = 0.01500376
# Iteration 256, loss = 0.01487844
# Iteration 257, loss = 0.01475052
# Iteration 258, loss = 0.01466980
# Iteration 259, loss = 0.01454076
# Iteration 260, loss = 0.01444657
# Iteration 261, loss = 0.01434938
# Iteration 262, loss = 0.01423022
# Iteration 263, loss = 0.01414045
# Iteration 264, loss = 0.01408434
# Iteration 265, loss = 0.01391868
# Iteration 266, loss = 0.01381837
# Iteration 267, loss = 0.01376775
# Iteration 268, loss = 0.01363984
# Iteration 269, loss = 0.01355131
# Iteration 270, loss = 0.01347258
# Iteration 271, loss = 0.01335514
# Iteration 272, loss = 0.01325951
# Iteration 273, loss = 0.01317550
# Iteration 274, loss = 0.01307250
# Iteration 275, loss = 0.01300493
# Iteration 276, loss = 0.01289822
# Iteration 277, loss = 0.01279875
# Iteration 278, loss = 0.01270783
# Iteration 279, loss = 0.01263158
# Iteration 280, loss = 0.01254906
# Iteration 281, loss = 0.01245395
# Iteration 282, loss = 0.01236898
# Iteration 283, loss = 0.01228754
# Iteration 284, loss = 0.01220338
# Iteration 285, loss = 0.01212678
# Iteration 286, loss = 0.01204753
# Iteration 287, loss = 0.01197029
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training set score: 1.000000
# Test set score: 0.969967

# %% [markdown]
# # Task: Test score vs architecture

# %%
#For this task set the maximum iterations to be 1000.
#Is there a 'best' architecture? 
#What about wider networks (62) or (128)?
#What about deeper networks (64,64) or (64,32) or (32,32,32)?
#Can you check the test score for different architectures?
# Define a list of architectures to try
hidden_layer_architectures = [
    (62,),           # Wider
    (128,),          # Wider
    (64, 64),        # Deeper
    (64, 32),        # Deeper
    (32, 32, 32),    # Even deeper
]
# Maximum iterations
max_iterations = 1000

# Initialize variables to store the results
results = []

# Loop through each architecture and evaluate the MLPClassifier
for architecture in hidden_layer_architectures:
    print(f"Testing architecture: {architecture}")
    
    mlp = MLPClassifier(hidden_layer_sizes=architecture, 
                        max_iter=max_iterations, 
                        activation='logistic', 
                        random_state=42, 
                        verbose=False)

    with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=ConvergenceWarning, module="sklearn")
        mlp.fit(X_train, y_train)

    train_score = mlp.score(X_train, y_train)
    test_score = mlp.score(X_test, y_test)

    # Store the results
    results.append((architecture, train_score, test_score))

    print(f"Training set score: {train_score}")
    print(f"Test set score: {test_score}")

# Display the results
print("\nResults:")
for architecture, train_score, test_score in results:
    print(f"Architecture: {architecture}, Training Score: {train_score}, Test Score: {test_score}")
# Out:
# Testing architecture: (62,)
# Training set score: 1.0
# Test set score: 0.9699666295884316
# Testing architecture: (128,)
# Training set score: 1.0
# Test set score: 0.9699666295884316
# Testing architecture: (64, 64)
# Training set score: 1.0
# Test set score: 0.9610678531701891
# Testing architecture: (64, 32)
# Training set score: 1.0
# Test set score: 0.9588431590656284
# Testing architecture: (32, 32, 32)
# Training set score: 1.0
# Test set score: 0.9365962180200222
#
# Results:
# Architecture: (62,), Training Score: 1.0, Test Score: 0.9699666295884316
# Architecture: (128,), Training Score: 1.0, Test Score: 0.9699666295884316
# Architecture: (64, 64), Training Score: 1.0, Test Score: 0.9610678531701891
# Architecture: (64, 32), Training Score: 1.0, Test Score: 0.9588431590656284
# Architecture: (32, 32, 32), Training Score: 1.0, Test Score: 0.9365962180200222

# %% [markdown]
# # Probabilities of Detections

# %%
def plot_detection_probabilities(entry):
    probabilities = mlp.predict_proba([entry])[0]
    print(np.sum(probabilities)) #What do you think this should be? 
    plt.bar(np.arange(10), probabilities, color='k')
    plt.xticks(np.arange(10))
    plt.ylabel("probability")
    plt.xlabel("digit labels")
    plt.show()

# %%
plot_detection_probabilities(X_test[42])
print_heatmap(X_test[42])

# %% [markdown]
# # Task: High confidence vs low confidence classifications

# %%
#Try different entries from the test set to see if you can find a low confidence example
#What would such an example look like in the probability distribution plot?
